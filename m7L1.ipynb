# %% [markdown]
# <a href="https://www.kaggle.com/code/aswin2021/m7l1-ipynb?scriptVersionId=206417788" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Numpy

# %%
heights = [132,200,141,80,181]
heights
# Out:
# [132, 200, 141, 80, 181]

# %%
heights* 0.2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 heights* 0.2
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
import numpy as np
np_ht = np.array(heights)
np_ht *0.3
# Out:
# array([39.6, 60. , 42.3, 24. , 54.3])

# %%
type(np_ht)
# Out:
# numpy.ndarray

# %%
list1 = [2,4,1,5]
list2 = [4,2,8,9]
list1 + list2
# Out:
# [2, 4, 1, 5, 4, 2, 8, 9]

# %%
np.array(list1) + np.array(list2)
# Out:
# array([ 6,  6,  9, 14])
