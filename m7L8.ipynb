Office Supplies', 'Technology', 'Furniture', 'Office Supplies', 'Technology', 
    'Furniture', 'Office Supplies', 'Technology', 'Furniture', 'Office Supplies', 
    'Technology', 'Furniture', 'Office Supplies', 'Technology', 'Furniture', 
    'Office Supplies', 'Technology', 'Furniture', 'Office Supplies', 'Technology', 
    'Furniture', 'Office Supplies', 'Technology', 'Furniture', 'Office Supplies', 
    'Technology', 'Furniture', 'Office Supplies', 'Technology', 'Furniture'
])


country = np.array([
    'Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 
    'United States', 'United Kingdom', 'India', 'Zimbabwe', 'Zambia', 'Yemen', 
    'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 
    'India', 'Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 
    'Uruguay', 'United States', 'United Kingdom', 'India', 'Zimbabwe', 'Zambia', 
    'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 
    'United Kingdom', 'India', 'Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 
    'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 
    'India', 'Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 
    'Uruguay', 'United States', 'United Kingdom', 'India', 'Zimbabwe', 'Zambia', 
    'Yemen', 'Vietnam', 'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 
    'United Kingdom', 'India', 'Zimbabwe', 'Zambia', 'Yemen', 'Vietnam', 
    'Venezuela', 'Uzbekistan', 'Uruguay', 'United States', 'United Kingdom', 'India'
])

# %%
len(product_category)
# Out:
# 80

# %%
plt.scatter(profit,sales,alpha=0.6,s=5)
plt.title("Sales across product categores \n", fontdict = { 'fontsize':15, 'fontweight':5, 'color': 'red'})

plt.xlabel("\n product categories", fontdict={'fontsize':13, 'fontweight':5, 'color':'blue'})
plt.ylabel("\nsales", fontdict={'fontsize':13, 'fontweight':5, 'color':'blue'})



plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot for Technology category
plt.scatter(profit[product_category == 'Technology'], sales[product_category == 'Technology'], 
            c="green", alpha=0.7, s=40, label="Technology")

# Scatter plot for Office Supplies category
plt.scatter(profit[product_category == 'Office Supplies'], sales[product_category == 'Office Supplies'], 
            c="yellow", alpha=0.7, s=40, label="Office Supplies")

# Scatter plot for Furniture category
plt.scatter(profit[product_category == 'Furniture'], sales[product_category == 'Furniture'], 
            c="cyan", alpha=0.7, s=40, label="Furniture")

# Title and labels for axes
plt.title("Sales V/S Product Categories Across Various Countries and Products\n", 
          fontdict={'fontsize': 15, 'fontweight': 5, 'color': 'red'})

plt.xlabel("\nProduct Categories", fontdict={'fontsize': 13, 'fontweight': 5, 'color': 'blue'})
plt.ylabel("\nSales", fontdict={'fontsize': 13, 'fontweight': 5, 'color': 'blue'})

# Show legend
plt.legend()

# Display plot
plt.show()
